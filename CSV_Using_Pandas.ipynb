# %%
import pandas as pd

# %%
dict={"Subjects":['English','Geography','History','Political Science','Computer Science','Physics','Chemistry','Maths','Biology'],"Marks":[70,75,80,85,80,95,90,97,85]}

dt=pd.DataFrame(dict)
print(dt)
# Out:
#             Subjects  Marks
# 0            English     70
# 1          Geography     75
# 2            History     80
# 3  Political Science     85
# 4   Computer Science     80
# 5            Physics     95
# 6          Chemistry     90
# 7              Maths     97
# 8            Biology     85

# %%
dt.to_csv("Student.csv")
